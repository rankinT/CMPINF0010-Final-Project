# %%
import pandas as pd
import numpy as np
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

enroll = pd.read_csv("school-enrollment.csv")

# %%
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>
